# %%
import argparse
from typing import Optional

import matplotlib.pyplot as plt
import numpy as np

from isc.io import read_ground_truth, read_predictions
from isc.metrics import evaluate, Metrics, print_metrics

import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np

# %%
d_precision = []
d_recall = []
d_racall_10 = []
for i in range(1, 26):
    predictions = read_predictions(f"./data/disc/disc/{i}/matrix_no_norm.csv")
    gts = read_ground_truth('./data/disc/ground_truth.csv')
    metrics = evaluate(gts, predictions)
    d_precision.append(metrics.average_precision)
    d_recall.append(metrics.recall_at_rank1)
    d_racall_10.append(metrics.recall_at_rank10)
    if metrics.recall_at_p90 is None:
        print(f"| {str(i).zfill(2)}            | {metrics.average_precision:.5f}               | -                 | -                   | {metrics.recall_at_rank1:.5f}              | {metrics.recall_at_rank10:.5f}               |")
    else:
        print(f"| {str(i).zfill(2)}            | {metrics.average_precision:.5f}               | {metrics.recall_at_p90:.5f}           | {metrics.threshold_at_p90:g}             | {metrics.recall_at_rank1:.5f}              | {metrics.recall_at_rank10:.5f}               |")
# Out:
# | 01            | 0.17116               | 0.00251           | 0.999388             | 0.43389              | 0.48567               |
# | 02            | 0.17084               | 0.00201           | 0.999623             | 0.44143              | 0.49372               |
# | 03            | 0.15044               | 0.00201           | 0.999741             | 0.43037              | 0.47109               |
# | 04            | 0.18404               | 0.00101           | 0.999889             | 0.46104              | 0.50830               |
# | 05            | 0.14858               | 0.00050           | 0.999955             | 0.46405              | 0.50679               |
# | 06            | 0.08305               | 0.00201           | 0.999825             | 0.42283              | 0.46154               |
# | 07            | 0.11407               | 0.00503           | 0.998145             | 0.42534              | 0.45249               |
# | 08            | 0.18179               | 0.00452           | 0.99876             | 0.45953              | 0.50277               |
# | 09            | 0.18853               | 0.02815           | 0.991988             | 0.44897              | 0.50427               |
# | 10            | 0.15644               | 0.00050           | 0.999919             | 0.44696              | 0.50377               |
# | 11            | 0.24799               | 0.08145           | 0.974689             | 0.50628              | 0.56058               |
# | 12            | 0.23513               | 0.07240           | 0.978201             | 0.50880              | 0.57014               |
# | 13            | 0.23913               | 0.12469           | 0.965761             | 0.51232              | 0.56310               |
# | 14            | 0.24753               | 0.04274           | 0.982821             | 0.53293              | 0.59175               |
# | 15            | 0.26279               | 0.10256           | 0.97005             | 0.51684              | 0.57567               |
# | 16            | 0.23461               | 0.03369           | 0.983399             | 0.50679              | 0.56662               |
# | 17            | 0.22522               | 0.00201           | 0.999716             | 0.49774              | 0.57416               |
# | 18            | 0.18689               | 0.00151           | 0.999829             | 0.50578              | 0.56008               |
# | 19            | 0.20260               | 0.00302           | 0.998998             | 0.48316              | 0.54651               |
# | 20            | 0.24214               | 0.05581           | 0.978108             | 0.49422              | 0.55003               |
# | 21            | 0.28278               | 0.12117           | 0.960576             | 0.50427              | 0.56511               |
# | 22            | 0.25039               | 0.04827           | 0.98001             | 0.51433              | 0.58019               |
# | 23            | 0.31026               | 0.15586           | 0.954247             | 0.50478              | 0.56410               |
# | 24            | 0.30352               | 0.18049           | 0.949393             | 0.50075              | 0.56360               |
# | 25            | 0.28337               | 0.16893           | 0.949241             | 0.49070              | 0.55455               |

# %%
q_precision = []
q_recall = []
q_racall_10 = []
for i in range(1, 26):
    predictions = read_predictions(f"./data/disc/glv2_q/{i}/matrix_no_norm.csv")
    gts = read_ground_truth('./data/disc/ground_truth.csv')
    metrics = evaluate(gts, predictions)
    q_precision.append(metrics.average_precision)
    q_recall.append(metrics.recall_at_rank1)
    q_racall_10.append(metrics.recall_at_rank10)
    if metrics.recall_at_p90 is None:
        print(f"| {str(i).zfill(2)}            | {metrics.average_precision:.5f}               | -                 | -                   | {metrics.recall_at_rank1:.5f}              | {metrics.recall_at_rank10:.5f}               |")
    else:
        print(f"| {str(i).zfill(2)}            | {metrics.average_precision:.5f}               | {metrics.recall_at_p90:.5f}           | {metrics.threshold_at_p90:g}             | {metrics.recall_at_rank1:.5f}              | {metrics.recall_at_rank10:.5f}               |")
# Out:
# | 01            | 0.24217               | 0.16189           | 0.98396             | 0.44796              | 0.47813               |
# | 02            | 0.22555               | 0.12217           | 0.984143             | 0.45651              | 0.49522               |
# | 03            | 0.21671               | 0.12469           | 0.978276             | 0.43992              | 0.47813               |
# | 04            | 0.22263               | 0.13072           | 0.978349             | 0.44042              | 0.48617               |
# | 05            | 0.19426               | 0.11815           | 0.977757             | 0.40774              | 0.45199               |
# | 06            | 0.16501               | 0.10709           | 0.977909             | 0.41931              | 0.46405               |
# | 07            | 0.21698               | 0.13122           | 0.976589             | 0.45249              | 0.49522               |
# | 08            | 0.22867               | 0.14279           | 0.973195             | 0.43841              | 0.49975               |
# | 09            | 0.14728               | 0.05028           | 0.984939             | 0.37054              | 0.41579               |
# | 10            | 0.18543               | 0.11865           | 0.97539             | 0.39970              | 0.44746               |
# | 11            | 0.15029               | 0.08798           | 0.979758             | 0.41579              | 0.45701               |
# | 12            | 0.18942               | 0.11865           | 0.972833             | 0.43439              | 0.48819               |
# | 13            | 0.20966               | 0.13776           | 0.965244             | 0.44796              | 0.50327               |
# | 14            | 0.16510               | 0.07491           | 0.975682             | 0.42936              | 0.48366               |
# | 15            | 0.18857               | 0.12267           | 0.963748             | 0.43288              | 0.48617               |
# | 16            | 0.22037               | 0.14580           | 0.960341             | 0.45601              | 0.51433               |
# | 17            | 0.17878               | 0.10508           | 0.965892             | 0.41629              | 0.48316               |
# | 18            | 0.18029               | 0.09050           | 0.967607             | 0.43238              | 0.49271               |
# | 19            | 0.17767               | 0.10106           | 0.963219             | 0.45249              | 0.50830               |
# | 20            | 0.17093               | 0.09955           | 0.962113             | 0.42584              | 0.48416               |
# | 21            | 0.18783               | 0.10508           | 0.960828             | 0.44193              | 0.50075               |
# | 22            | 0.19393               | 0.11111           | 0.955878             | 0.44143              | 0.50729               |
# | 23            | 0.21522               | 0.13575           | 0.952324             | 0.44595              | 0.50980               |
# | 24            | 0.21431               | 0.11966           | 0.958022             | 0.47210              | 0.52690               |
# | 25            | 0.18914               | 0.09351           | 0.962183             | 0.45902              | 0.51433               |

# %%
t_precision = []
t_recall = []
t_racall_10 = []
for i in range(1, 26):
    predictions = read_predictions(f"./data/disc/glv2_t/{i}/matrix_no_norm.csv")
    gts = read_ground_truth('./data/disc/ground_truth.csv')
    metrics = evaluate(gts, predictions)
    t_precision.append(metrics.average_precision)
    t_recall.append(metrics.recall_at_rank1)
    t_racall_10.append(metrics.recall_at_rank10)
    if metrics.recall_at_p90 is None:
        print(f"| {str(i).zfill(2)}            | {metrics.average_precision:.5f}               | -                 | -                   | {metrics.recall_at_rank1:.5f}              | {metrics.recall_at_rank10:.5f}               |")
    else:
        print(f"| {str(i).zfill(2)}            | {metrics.average_precision:.5f}               | {metrics.recall_at_p90:.5f}           | {metrics.threshold_at_p90:g}             | {metrics.recall_at_rank1:.5f}              | {metrics.recall_at_rank10:.5f}               |")
# Out:
# | 01            | 0.21432               | 0.05229           | 0.991693             | 0.45048              | 0.48768               |
# | 02            | 0.09827               | 0.00151           | 0.999838             | 0.43590              | 0.47059               |
# | 03            | 0.17786               | 0.00201           | 0.999732             | 0.46204              | 0.51383               |
# | 04            | 0.13057               | 0.00201           | 0.999823             | 0.44394              | 0.47813               |
# | 05            | 0.13306               | 0.00151           | 0.999859             | 0.44143              | 0.48819               |
# | 06            | 0.13653               | 0.00101           | 0.999887             | 0.44093              | 0.48718               |
# | 07            | 0.12680               | 0.00101           | 0.999886             | 0.44997              | 0.48919               |
# | 08            | 0.10733               | 0.00151           | 0.999868             | 0.44545              | 0.48617               |
# | 09            | 0.10926               | 0.00251           | 0.999648             | 0.41730              | 0.45400               |
# | 10            | 0.06695               | 0.00302           | 0.99953             | 0.39970              | 0.44646               |
# | 11            | 0.16103               | 0.00201           | 0.999655             | 0.49070              | 0.52388               |
# | 12            | 0.15313               | 0.00151           | 0.999719             | 0.48165              | 0.52740               |
# | 13            | 0.17748               | 0.00251           | 0.999317             | 0.47763              | 0.53494               |
# | 14            | 0.20002               | 0.00251           | 0.999173             | 0.51031              | 0.56058               |
# | 15            | 0.15770               | 0.00201           | 0.999656             | 0.47662              | 0.52388               |
# | 16            | 0.14439               | 0.00101           | 0.999861             | 0.48014              | 0.52740               |
# | 17            | 0.22768               | 0.05882           | 0.976469             | 0.50980              | 0.55958               |
# | 18            | 0.17598               | 0.00402           | 0.998607             | 0.48969              | 0.53394               |
# | 19            | 0.17149               | 0.00302           | 0.999028             | 0.49522              | 0.54952               |
# | 20            | 0.23424               | 0.04525           | 0.976156             | 0.50277              | 0.55958               |
# | 21            | 0.21296               | 0.06938           | 0.969991             | 0.48969              | 0.54198               |
# | 22            | 0.10900               | 0.00151           | 0.9998             | 0.47562              | 0.51986               |
# | 23            | 0.16937               | 0.00452           | 0.99764             | 0.49271              | 0.54751               |
# | 24            | 0.15799               | 0.00201           | 0.999725             | 0.48215              | 0.53544               |
# | 25            | 0.17246               | 0.01810           | 0.987532             | 0.48869              | 0.54651               |

# %%
epochs = np.arange(1, 26, 1)
plt.plot(epochs, d_precision, 'o-r', label='ViT-D')
plt.plot(epochs, t_precision, 'o-g', label='ViT-LT')
plt.plot(epochs, q_precision, 'o-b', label='ViT-LQ')
plt.xlim(1, 25)
plt.ylim(bottom=0, top=None)
plt.xticks([1, 5, 10, 15, 20, 25])
plt.xlabel("Epocha")
plt.legend(loc='upper right')
# plt.savefig('./glv2_q_loss.eps', format='eps')
plt.show()

# %%
epochs = np.arange(1, 26, 1)
plt.plot(epochs, d_precision, 'o-r', label='P')
plt.plot(epochs, d_recall, 'o-g', label='R@1')
plt.plot(epochs, d_racall_10, 'o-b', label='R@10')
plt.xlim(1, 25)
plt.ylim(bottom=0, top=None)
plt.xticks([1, 5, 10, 15, 20, 25])
plt.xlabel("Epocha")
plt.legend(loc='upper right')
# plt.savefig('./glv2_q_loss.eps', format='eps')
plt.show()

# %%
fig = plt.figure(layout='compressed', figsize=(10, 4))
subfigs = fig.subfigures(1, 3, wspace=0.07)
epochs = np.arange(1, 26, 1)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex=True, sharey=True, layout='compressed', figsize=(6, 4))

plt.xlim(1, 25)
plt.xticks([1, 5, 10, 15, 20, 25])
ax2.set_xlabel("Epocha")

ax1.plot(epochs, d_precision, 'r', label='μAP')
ax1.plot(epochs, d_recall, 'g', label='R@1')
ax1.plot(epochs, d_racall_10, 'b', label='R@10')
ax1.set_title('ViT-D')

ax2.plot(epochs, t_precision, 'r')
ax2.plot(epochs, t_recall, 'g')
ax2.plot(epochs, t_racall_10, 'b')
ax2.set_title('ViT-LT')

ax3.plot(epochs, q_precision, 'r')
ax3.plot(epochs, q_recall, 'g')
ax3.plot(epochs, q_racall_10, 'b')
ax3.set_title('ViT-LQ')

fig.legend(loc='outside upper right')
plt.savefig('./disc_vit_metrics.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
