# %%
from PIL import Image
from utils.augmentation_chain import get_augmentation_chain

# %%
anchor_img = Image.open('/media/augustinas/T7/DISC2021/SmallData/images/train/T000001.jpg')

# %%
augmentations = get_augmentation_chain(image_path='/media/augustinas/T7/DISC2021/SmallData/images/train/', mean=1,
                                       std=1)

# %%
augmented_img = augmentations(anchor_img)

# %%
augmented_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
