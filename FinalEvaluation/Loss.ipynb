# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
epochs = np.arange(1, 26, 1)

# %%
disc21_loss = [
    0.0048, 0.0015, 0.0011, 0.0010, 0.0010,
    0.0007, 0.0008, 0.0008, 0.0006, 0.0007,
    0.0086, 0.0059, 0.0047, 0.0038, 0.0038,
    0.0033, 0.0035, 0.0034, 0.0035, 0.0034,
    0.0027, 0.0028, 0.0026, 0.0028, 0.0027
]

# %%
plt.plot(epochs, disc21_loss, 'o-b')
plt.xlim(1, 25)
plt.ylim(bottom=0, top=None)
plt.xticks([1, 5, 10, 15, 20, 25])
plt.xlabel("Epocha")
plt.ylabel("Tikslo funkcijos įvertis")
plt.gcf().set_size_inches(6, 4)
plt.savefig('./disc21_loss.eps', format='eps')
plt.show()

# %%
glv2_t_loss = [
    0.0053, 0.0019, 0.0016, 0.0012, 0.0012,
    0.0011, 0.0010, 0.0009, 0.0010, 0.0008,
    0.0103, 0.0068, 0.0064, 0.0054, 0.0055,
    0.0053, 0.0045, 0.0040, 0.0040, 0.0039,
    0.0037, 0.0037, 0.0032, 0.0033, 0.0032
]

# %%
plt.plot(epochs, glv2_t_loss, 'o-b')
plt.xlim(1, 25)
plt.ylim(bottom=0, top=None)
plt.xticks([1, 5, 10, 15, 20, 25])
plt.xlabel("Epocha")
plt.ylabel("Tikslo funkcijos įvertis")
plt.gcf().set_size_inches(6, 4)
plt.savefig('./glv2_t_loss.eps', format='eps')
plt.show()

# %%
glv2_q_loss = [
    0.1401, 0.0720, 0.0536, 0.0446, 0.0397,
    0.0353, 0.0328, 0.0300, 0.0289, 0.0278,
    0.6336, 0.5536, 0.5101, 0.4785, 0.4526,
    0.4289, 0.4131, 0.3921, 0.3757, 0.3628,
    0.3470, 0.3358, 0.3213, 0.3163, 0.3064
]

# %%
plt.plot(epochs, glv2_q_loss, 'o-b')
plt.xlim(1, 25)
plt.ylim(bottom=0, top=None)
plt.xticks([1, 5, 10, 15, 20, 25])
plt.xlabel("Epocha")
plt.ylabel("Tikslo funkcijos įvertis")
plt.gcf().set_size_inches(6, 4)
plt.savefig('./glv2_q_loss.eps', format='eps')
plt.show()
